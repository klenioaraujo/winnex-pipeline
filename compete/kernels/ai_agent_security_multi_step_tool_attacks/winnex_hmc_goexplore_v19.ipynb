# %% [markdown]
# # Winnex HMC Go-Explore v19
# **BSL 1.1 | pay@winnex.ai**

# %%
import base64, os
code_b64 = "..."
with open('/kaggle/working/attack.py', 'w') as f:
    f.write(base64.b64decode(code_b64).decode())
os.chmod('/kaggle/working/attack.py', 0o644)
print('Written', os.path.getsize('/kaggle/working/attack.py'), 'bytes to /kaggle/working/attack.py')
